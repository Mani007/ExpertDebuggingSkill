# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so
import plotly  
import sklearn as sklearn

# %%
from sklearn.datasets import load_wine
wine_data = load_wine(as_frame=True)
wine_df = wine_data.frame

print(wine_df.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
sns.heatmap(wine_df.corr(), annot=True, linewidth=.5)
# Out:
# <Axes: >

# %%
mat = np.triu(wine_df.corr()) # upper triangular matrix is removed

# %%
mattri = np.tri(wine_df.corr()) # traingue matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12616\4242790231.py in ?()
# ----> 1 mattri = np.tri(wine_df.corr()) # traingue matrix
#
# e:\Document backup\Software Debugging and testing skills\.env\Lib\site-packages\numpy\lib\_twodim_base_impl.py in ?(N, M, k, dtype, like)
#     423
#     424     if M is None:
#     425         M = N
#     426
# --> 427     m = greater_equal.outer(arange(N, dtype=_min_int(0, N)),
#     428                             arange(-k, M-k, dtype=_min_int(-k, M - k)))
#     429
#     430     # Avoid making a copy if the requested type is already bool
#
# e:\Document backup\Software Debugging and testing skills\.env\Lib\site-packages\numpy\lib\_twodim_base_impl.py in ?(low, high)
#      34 def _min_int(low, high):
#      35     """ get small int that fits the range """
# ---> 36     if high <= i1.max and low >= i1.min:
# ...

# %%
matl = np.tril(wine_df.corr()) #lower trangular matrix is removed

# %%
plt.figure(figsize=(9,9))

# %%
sns.heatmap(wine_df.corr(), annot=True, linewidth=.5, cmap='bwr', vmin=-1, vmax=1, mask=mat, square=True,  fmt=".1f")
plt.show()
